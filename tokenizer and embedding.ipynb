# %%
import numpy as np 
import pandas as pd 
import os
import gc
import psutil

# %%
print(os.listdir('E:\\kaggle\\Avito Demand Prediction Challenge\\features\\dataset\\'))
# Out:
# ['embedding_matrix1.npy', 'testfinal.csv', 'testready.csv', 'testtemp.csv', 'trainfinal.csv', 'trainready.csv', 'traintemp.csv']

# %%
path='E:\\kaggle\\Avito Demand Prediction Challenge\\features\\dataset\\'
test=pd.read_csv(path+'testready.csv',header=0)
train=pd.read_csv(path+'trainready.csv',header=0)
test['deal_probability']=-1

data=pd.concat([train,test],ignore_index=True)
del train,test
gc.collect()
data
# Out:
#               item_id       user_id  \
# 0        b912c3c6a6ad  e00f8ff2eaf9
# 1        2dac0150717d  39aeb48f0017
# 2        ba83aefab5dc  91e2f88dd6e3
# 3        02996f1dd2ea  bf5cccea572d
# 4        7c90be56d2ab  ef50846afc0b
# 5        51e0962387f7  bbfad0b1ad0a
# 6        c4f260a2b48a  08f469d2e6f7
# 7        6b71309d6a8a  fef86baa002c
# 8        c5b969cb63a2  055825270190
# 9        b1570962e68c  f9e8f831d94c
# 10       d5480bb4a6e4  d46200940f37
# 11       86f41f50d8c1  35c2b6b654e0
# 12       645237cb3601  fc9a38b79414
# 13       df2116f34563  3ce3c2318b16
# 14       a97943ae8158  f643d87dd23c
# 15       4b6abd0a5921  94de2b374869
# 16       7896ef8fe482  007c6bd858cb
# 17       7882b1e77748  7a3fda0cdf94
# 18       071e1ed13c5c  325cacee50f4
# 19       0658628930d4  27c2d83b766e
# 20       ea12aec32ec3  06ee4ff4e99c
# 21       838a82cec0a6  5d44315f6d90
# 22       de310e6aae86  0178e6308f38
# 23       08b24e170109  6630d724bbf5
# 24       065a4daba35f  19a5cd02c89b
# ...

# %%
textfeats = ["description","title"]
for cols in textfeats:
    data[cols] = data[cols].astype(str) 
    data[cols] = data[cols].astype(str).fillna('nicapotato') # FILL NA
    data[cols] = data[cols].str.lower() # Lowercase all text, so that capitalized words dont get treated differently
    data[cols + '_num_words'] = data[cols].apply(lambda comment: len(comment.split())) # Count number of Words
    data[cols + '_num_unique_words'] = data[cols].apply(lambda comment: len(set(w for w in comment.split())))
    data[cols + '_words_vs_unique'] = data[cols+'_num_unique_words'] / data[cols+'_num_words']
data
# Out:
#               item_id       user_id  \
# 0        b912c3c6a6ad  e00f8ff2eaf9
# 1        2dac0150717d  39aeb48f0017
# 2        ba83aefab5dc  91e2f88dd6e3
# 3        02996f1dd2ea  bf5cccea572d
# 4        7c90be56d2ab  ef50846afc0b
# 5        51e0962387f7  bbfad0b1ad0a
# 6        c4f260a2b48a  08f469d2e6f7
# 7        6b71309d6a8a  fef86baa002c
# 8        c5b969cb63a2  055825270190
# 9        b1570962e68c  f9e8f831d94c
# 10       d5480bb4a6e4  d46200940f37
# 11       86f41f50d8c1  35c2b6b654e0
# 12       645237cb3601  fc9a38b79414
# 13       df2116f34563  3ce3c2318b16
# 14       a97943ae8158  f643d87dd23c
# 15       4b6abd0a5921  94de2b374869
# 16       7896ef8fe482  007c6bd858cb
# 17       7882b1e77748  7a3fda0cdf94
# 18       071e1ed13c5c  325cacee50f4
# 19       0658628930d4  27c2d83b766e
# 20       ea12aec32ec3  06ee4ff4e99c
# 21       838a82cec0a6  5d44315f6d90
# 22       de310e6aae86  0178e6308f38
# 23       08b24e170109  6630d724bbf5
# 24       065a4daba35f  19a5cd02c89b
# ...

# %%
data['description_num_words']=np.clip(data['description_num_words'],1,128)
data['description_num_words']=data['description_num_words']/128
data['description_num_unique_words']=np.clip(data['description_num_unique_words'],1,128)
data['description_num_unique_words']=data['description_num_unique_words']/128
data['title_num_words']=np.clip(data['title_num_words'],1,16)
data['title_num_words']=data['title_num_words']/16
data['title_num_unique_words']=np.clip(data['title_num_unique_words'],1,16)
data['title_num_unique_words']=data['title_num_unique_words']/16
data
# Out:
#               item_id       user_id  \
# 0        b912c3c6a6ad  e00f8ff2eaf9
# 1        2dac0150717d  39aeb48f0017
# 2        ba83aefab5dc  91e2f88dd6e3
# 3        02996f1dd2ea  bf5cccea572d
# 4        7c90be56d2ab  ef50846afc0b
# 5        51e0962387f7  bbfad0b1ad0a
# 6        c4f260a2b48a  08f469d2e6f7
# 7        6b71309d6a8a  fef86baa002c
# 8        c5b969cb63a2  055825270190
# 9        b1570962e68c  f9e8f831d94c
# 10       d5480bb4a6e4  d46200940f37
# 11       86f41f50d8c1  35c2b6b654e0
# 12       645237cb3601  fc9a38b79414
# 13       df2116f34563  3ce3c2318b16
# 14       a97943ae8158  f643d87dd23c
# 15       4b6abd0a5921  94de2b374869
# 16       7896ef8fe482  007c6bd858cb
# 17       7882b1e77748  7a3fda0cdf94
# 18       071e1ed13c5c  325cacee50f4
# 19       0658628930d4  27c2d83b766e
# 20       ea12aec32ec3  06ee4ff4e99c
# 21       838a82cec0a6  5d44315f6d90
# 22       de310e6aae86  0178e6308f38
# 23       08b24e170109  6630d724bbf5
# 24       065a4daba35f  19a5cd02c89b
# ...

# %%
columns=['item_id', 'user_id', 'title', 'description',
         'region', 'city', 'parent_category_name','category_name', 'user_type','activation_date',
         'param_1', 'param123','image_top_1','cluster_5', 'cluster_10','cluster_20','item_seq_number',         
         'para_num','item_seq_count','item_seq_deal_avg',   
         'deal_prob_avg', 'deal_prob_avg_par', 'count_avg', 'count_avg_par',
         'dis_days', 'edit_time', 'item_num',
         'count',  'cus', 'ship', 'r_cus', 'r_ship', 'all_cus', 
         'avg_r','avg_g', 'avg_b', 'blurrness', 'dullness', 'whiteness',
         'avg_pixel_width', 'width', 'height', 'size', 
         'resnet_1', 'resnet_3','resnet_5', 'resnet_ratio1', 'resnet_ratio2', 
         'incept_1', 'incept_3','incept_5', 'incept_ratio1', 'incept_ratio2', 
         'xcept_1', 'xcept_3','xcept_5', 'xcept_ratio1', 'xcept_ratio2',
         'description_num_words','description_num_unique_words','description_words_vs_unique',
         'title_num_words','title_num_unique_words','title_words_vs_unique',
         'price','deal_probability']
data=data[columns]
gc.collect()
data
# Out:
#               item_id       user_id  \
# 0        b912c3c6a6ad  e00f8ff2eaf9
# 1        2dac0150717d  39aeb48f0017
# 2        ba83aefab5dc  91e2f88dd6e3
# 3        02996f1dd2ea  bf5cccea572d
# 4        7c90be56d2ab  ef50846afc0b
# 5        51e0962387f7  bbfad0b1ad0a
# 6        c4f260a2b48a  08f469d2e6f7
# 7        6b71309d6a8a  fef86baa002c
# 8        c5b969cb63a2  055825270190
# 9        b1570962e68c  f9e8f831d94c
# 10       d5480bb4a6e4  d46200940f37
# 11       86f41f50d8c1  35c2b6b654e0
# 12       645237cb3601  fc9a38b79414
# 13       df2116f34563  3ce3c2318b16
# 14       a97943ae8158  f643d87dd23c
# 15       4b6abd0a5921  94de2b374869
# 16       7896ef8fe482  007c6bd858cb
# 17       7882b1e77748  7a3fda0cdf94
# 18       071e1ed13c5c  325cacee50f4
# 19       0658628930d4  27c2d83b766e
# 20       ea12aec32ec3  06ee4ff4e99c
# 21       838a82cec0a6  5d44315f6d90
# 22       de310e6aae86  0178e6308f38
# 23       08b24e170109  6630d724bbf5
# 24       065a4daba35f  19a5cd02c89b
# ...

# %%
train=data[data['deal_probability']>=0]
test=data[data['deal_probability']==-1]
test=test.drop(['deal_probability'], axis=1)
del data
gc.collect()
train.to_csv('traintemp.csv', index=False)
test.to_csv('testtemp.csv', index=False)
