# %%
import numpy as np 
import pandas as pd 
import os
import gc
import psutil

# %%
path='E:\\kaggle\\Avito Demand Prediction Challenge\\features\\dataset\\'
data=pd.read_csv(path+'trainfinal.csv',header=0)
rnn=pd.read_csv(path+'RNNtrain.csv',header=0)
data=pd.merge(data,rnn, on=['item_id'],how='left')
data.to_csv('trainx.csv', index=False)
data
# Out:
#               item_id       user_id  \
# 0        6119e3c63171  690dafdfdd2e
# 1        4b6978101210  966b1266b674
# 2        c02922f437bd  fdf14710e8a7
# 3        2507374ba678  c4e2b6dcd48a
# 4        64f68a7b4fc1  e08bcc508b10
# 5        481a10f357cb  7e20e14ea20f
# 6        94e04dc3356c  722b05558098
# 7        6a615832a85b  9abcaff39a6f
# 8        d096e9a969b1  8288886e2593
# 9        81945ec9ebe2  64dccae425bd
# 10       43af0d76d97f  158de31dd90b
# 11       00154e1d7334  838127830416
# 12       f8d1b84514b0  d5568c14b602
# 13       b373603575c7  4734f29194d9
# 14       71a6ca08b25b  94b56c6de360
# 15       d6525b600009  14a765004c5d
# 16       431687a55d66  dbd0f520a01c
# 17       c0c2167de859  5836befce0a9
# 18       1e60887583fd  99e32058ed15
# 19       f364984333b0  fd2aeba68dd2
# 20       7b3b13e9799b  e41a054104c0
# 21       c2f2283c3122  d877496fde14
# 22       760a5d63b624  369d97002d8b
# 23       9445aaf5e350  4f1475814b64
# 24       15df7cc657d0  2e9a2f1bef59
# ...

# %%
path='E:\\kaggle\\Avito Demand Prediction Challenge\\features\\dataset\\'
data=pd.read_csv(path+'testfinal.csv',header=0)
rnn=pd.read_csv(path+'RNNtest.csv',header=0)
data=pd.merge(data,rnn, on=['item_id'],how='left')
data.to_csv('testx.csv', index=False)
data
# Out:
#              item_id       user_id  \
# 0       6544e41a8817  dbe73ad6e4b5
# 1       65b9484d670f  2e11806abe57
# 2       8bab230b2ecd  0b850bbebb10
# 3       8e348601fefc  5f1d5c3ce0da
# 4       8bd2fe400b89  23e2d97bfc7f
# 5       c63dbd6c657f  c2a632af2602
# 6       6d1a410df86e  b239811ad530
# 7       e8d3e7922b80  d85fa02e6341
# 8       2bc1ab208462  ae6586719bec
# 9       7e05d77a9181  30ad26d633ef
# 10      e2ec19a3ca2b  cf6fadee4837
# 11      68069bfc06c2  10564039a396
# 12      595842ba248a  281ca2f11fa7
# 13      4130d5cfc5de  81918b937f5d
# 14      c21ede41b256  d1668f293e95
# 15      f56e4684ceda  93bc220850f8
# 16      e7ab88d19965  34f09fa2f960
# 17      81c1cd9f4e4e  5028de9fa9ad
# 18      2c989cea0e97  60077d1dec96
# 19      36a35020ebeb  dd0e2e85dec5
# 20      60b0cc9cf25e  dcba22bc5ba6
# 21      ac0a01acccc2  38663374247f
# 22      683c444d6a40  f3322e64cc1a
# 23      5580ccd3358a  1b5ad0f05cbe
# 24      4596527723ec  dfd0bf569ccd
# ...

# %%
da
